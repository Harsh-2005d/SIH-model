# %%
import sys
sys.path.append("./sat.py")
import importlib
import sat
importlib.reload(sat)
from sat import process_satellite_data

# %%
process_satellite_data(
    "./data/satellite/MM_HCHO_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_CO_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_H20_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_NO2_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_O3_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_SO2_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_cloud_index.tif",
    "./processed_data"
)
process_satellite_data(
    "./data/satellite/MM_CH4_index.tif",
    "./processed_data"
)
re=process_satellite_data(
    "./data/satellite/MM_aerosol_index_22-25.tif",
    "./processed_data"
)
# Out:
# Loaded raster ./data/satellite/MM_HCHO_index.tif → shape (1096, 11, 12)
# → Imputing missing pixels ...
# → Scaling with StandardScaler ...
# Saved preprocessed arrays: ./processed_data
# Loaded raster ./data/satellite/MM_CO_index.tif → shape (1096, 11, 12)
# → Imputing missing pixels ...
# → Scaling with StandardScaler ...
# Saved preprocessed arrays: ./processed_data
# /home/wolverine/ML/model2.0/sat.py:39: RuntimeWarning: Mean of empty slice
#   mean = np.nanmean(stack, axis=0)
# Loaded raster ./data/satellite/MM_H20_index.tif → shape (1096, 11, 12)
# → Imputing missing pixels ...
# → Scaling with StandardScaler ...
# Saved preprocessed arrays: ./processed_data
# Loaded raster ./data/satellite/MM_NO2_index.tif → shape (1096, 11, 12)
# → Imputing missing pixels ...
# → Scaling with StandardScaler ...
# Saved preprocessed arrays: ./processed_data
# Loaded raster ./data/satellite/MM_O3_index.tif → shape (1096, 11, 12)
# → Imputing missing pixels ...
# ...
